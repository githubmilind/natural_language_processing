# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
from nltk import word_tokenize, pos_tag
import string
stop_words = set(stopwords.words('english'))

# %% [markdown]
# <b>Read Text File</b>

# %%
with open('news article.txt') as f:
    for line in f:
        text_line = line.strip()
        #text_line = "NASA awarded Elon Musk’s SpaceX a $2.9 billion contract to build the lunar lander."
        print(text_line)
        
        tokenized = word_tokenize(text_line)
        
        for i in tokenized:
            print("0>> ", i)
            workToken = word_tokenize(i)
            print("1>> ", workToken)
            
            workToken = [w for w in workToken if not w in stop_words]
            print("--> ", workToken)
            
            tagged = nltk.pos_tag(workToken)
            print("==> ")
            for t in tagged:
                print("a> ", t)
            
            ne_tree = nltk.ne_chunk(tagged)
            print(">>> ", ne_tree)
 
        break
# Out:
# Anglo-French Channel Tunnel operator Eurotunnel Monday announced a deal giving its creditor banks 45.5 percent of the company in return for wiping out one billion pounds ($1.56 billion) of its debt.
# 0>>  Anglo-French
# 1>>  ['Anglo-French']
# -->  ['Anglo-French']
# ==>
# a>  ('Anglo-French', 'JJ')
# >>>  (S Anglo-French/JJ)
# 0>>  Channel
# 1>>  ['Channel']
# -->  ['Channel']
# ==>
# a>  ('Channel', 'NNS')
# >>>  (S Channel/NNS)
# 0>>  Tunnel
# 1>>  ['Tunnel']
# -->  ['Tunnel']
# ==>
# a>  ('Tunnel', 'NN')
# >>>  (S (GPE Tunnel/NN))
# 0>>  operator
# 1>>  ['operator']
# -->  ['operator']
# ==>
# a>  ('operator', 'NN')
# >>>  (S operator/NN)
# 0>>  Eurotunnel
# 1>>  ['Eurotunnel']
# -->  ['Eurotunnel']
# ==>
# a>  ('Eurotunnel', 'NNS')
# >>>  (S Eurotunnel/NNS)
# 0>>  Monday
# 1>>  ['Monday']
# -->  ['Monday']
# ==>
# a>  ('Monday', 'NNP')
# >>>  (S Monday/NNP)
# 0>>  announced
# 1>>  ['announced']
# -->  ['announced']
# ==>
# a>  ('announced', 'VBD')
# >>>  (S announced/VBD)
# ...

# %%
with open('news article.txt') as f:
    content = f.read()
tokens = word_tokenize(content)
tags = nltk.pos_tag(tokens)
tags
# Out:
# [('Anglo-French', 'JJ'),
#  ('Channel', 'NNP'),
#  ('Tunnel', 'NNP'),
#  ('operator', 'NN'),
#  ('Eurotunnel', 'NNP'),
#  ('Monday', 'NNP'),
#  ('announced', 'VBD'),
#  ('a', 'DT'),
#  ('deal', 'NN'),
#  ('giving', 'VBG'),
#  ('its', 'PRP$'),
#  ('creditor', 'NN'),
#  ('banks', 'NNS'),
#  ('45.5', 'CD'),
#  ('percent', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('company', 'NN'),
#  ('in', 'IN'),
#  ('return', 'NN'),
#  ('for', 'IN'),
#  ('wiping', 'VBG'),
#  ('out', 'RP'),
#  ('one', 'CD'),
#  ('billion', 'CD'),
#  ('pounds', 'NNS'),
#  ('(', '('),
#  ('$', '$'),
#  ('1.56', 'CD'),
#  ('billion', 'CD'),
#  (')', ')'),
#  ('of', 'IN'),
#  ('its', 'PRP$'),
#  ('debt', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('long-awaited', 'JJ'),
#  ('restructuring', 'NN'),
#  ('brings', 'NNS'),
#  ('to', 'TO'),
#  ('an', 'DT'),
#  ('end', 'JJ'),
#  ('months', 'NNS'),
#  ('of', 'IN'),
#  ('wrangling', 'VBG'),
#  ('between', 'IN'),
#  ('Eurotunnel', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
# ...

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'
cp = nltk.RegexpParser(pattern)
cs = cp.parse(tags)
print(cs)
# Out:
# (S
#   Anglo-French/JJ
#   Channel/NNP
#   Tunnel/NNP
#   (NP operator/NN)
#   Eurotunnel/NNP
#   Monday/NNP
#   announced/VBD
#   (NP a/DT deal/NN)
#   giving/VBG
#   its/PRP$
#   (NP creditor/NN)
#   banks/NNS
#   45.5/CD
#   (NP percent/NN)
#   of/IN
#   (NP the/DT company/NN)
#   in/IN
#   (NP return/NN)
#   for/IN
#   wiping/VBG
#   out/RP
#   one/CD
#   billion/CD
#   pounds/NNS
#   (/(
#   $/$
#   1.56/CD
#   billion/CD
#   )/)
#   of/IN
#   its/PRP$
#   (NP debt/NN)
#   ./.
#   (NP The/DT long-awaited/JJ restructuring/NN)
#   brings/NNS
#   to/TO
#   an/DT
#   end/JJ
#   months/NNS
#   of/IN
#   wrangling/VBG
#   between/IN
#   Eurotunnel/NNP
#   and/CC
#   the/DT
#   225/CD
#   banks/NNS
#   to/TO
#   which/WDT
#   it/PRP
#   owes/VBZ
#   nearly/RB
#   nine/CD
#   billion/CD
#   pounds/NNS
#   (/(
#   $/$
#   14.1/CD
#   billion/CD
#   )/)
#   ./.
#   (NP The/DT deal/NN)
#   ,/,
#   announced/VBD
#   simultaneously/RB
#   in/IN
#   Paris/NNP
#   and/CC
#   London/NNP
# ...

# %%
ne_tree = nltk.ne_chunk(pos_tag(word_tokenize(content)))
print(ne_tree)
# Out:
# (S
#   Anglo-French/JJ
#   (ORGANIZATION Channel/NNP Tunnel/NNP)
#   operator/NN
#   (ORGANIZATION Eurotunnel/NNP)
#   Monday/NNP
#   announced/VBD
#   a/DT
#   deal/NN
#   giving/VBG
#   its/PRP$
#   creditor/NN
#   banks/NNS
#   45.5/CD
#   percent/NN
#   of/IN
#   the/DT
#   company/NN
#   in/IN
#   return/NN
#   for/IN
#   wiping/VBG
#   out/RP
#   one/CD
#   billion/CD
#   pounds/NNS
#   (/(
#   $/$
#   1.56/CD
#   billion/CD
#   )/)
#   of/IN
#   its/PRP$
#   debt/NN
#   ./.
#   The/DT
#   long-awaited/JJ
#   restructuring/NN
#   brings/NNS
#   to/TO
#   an/DT
#   end/JJ
#   months/NNS
#   of/IN
#   wrangling/VBG
#   between/IN
#   (ORGANIZATION Eurotunnel/NNP)
#   and/CC
#   the/DT
#   225/CD
#   banks/NNS
#   to/TO
#   which/WDT
#   it/PRP
#   owes/VBZ
#   nearly/RB
#   nine/CD
#   billion/CD
#   pounds/NNS
#   (/(
#   $/$
#   14.1/CD
#   billion/CD
#   )/)
#   ./.
#   The/DT
#   deal/NN
#   ,/,
#   announced/VBD
#   simultaneously/RB
#   in/IN
#   (GPE Paris/NNP)
#   and/CC
# ...

# %%
sent_text = nltk.sent_tokenize(content) # this gives us a list of sentences
# now loop over each sentence and tokenize it separately
for sentence in sent_text:
    tokenized_text = nltk.word_tokenize(sentence)
    
    tokens_without_sw = [word for word in tokenized_text if not ((word in stopwords.words()) or (word in string.punctuation))]
    
    print(tokens_without_sw)
    tagged = nltk.pos_tag(tokens_without_sw)
    print(tagged)
    ne = nltk.ne_chunk(tagged)
    print(ne)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# True
# ['Anglo-French', 'Channel', 'Tunnel', 'operator', 'Eurotunnel', 'Monday', 'announced', 'deal', 'giving', 'creditor', 'banks', '45.5', 'percent', 'company', 'return', 'wiping', 'billion', 'pounds', '1.56', 'billion', 'debt']
# [('Anglo-French', 'JJ'), ('Channel', 'NNP'), ('Tunnel', 'NNP'), ('operator', 'NN'), ('Eurotunnel', 'NNP'), ('Monday', 'NNP'), ('announced', 'VBD'), ('deal', 'NN'), ('giving', 'VBG'), ('creditor', 'NN'), ('banks', 'NNS'), ('45.5', 'CD'), ('percent', 'JJ'), ('company', 'NN'), ('return', 'VB'), ('wiping', 'VBG'), ('billion', 'CD'), ('pounds', 'NNS'), ('1.56', 'CD'), ('billion', 'CD'), ('debt', 'NN')]
# (S
#   Anglo-French/JJ
#   (ORGANIZATION Channel/NNP Tunnel/NNP)
#   operator/NN
#   (ORGANIZATION Eurotunnel/NNP)
#   Monday/NNP
#   announced/VBD
#   deal/NN
#   giving/VBG
#   creditor/NN
#   banks/NNS
#   45.5/CD
#   percent/JJ
#   company/NN
#   return/VB
#   wiping/VBG
#   billion/CD
#   pounds/NNS
#   1.56/CD
# ...
